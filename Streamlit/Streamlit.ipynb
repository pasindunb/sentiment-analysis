# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install --upgrade streamlit
# !pip install streamlit-option-menu
# !pip install pyngrok
# !pip install emoji

# %%
from pyngrok import ngrok
ngrok.set_auth_token("2MS4Ah1PQnFHCInonR9rYMWWuGF_wVfyF5dmbAwMsfXAmN7x")
url = ngrok.connect(port = '8501')
print(url)
# !streamlit run --server.port 80 drive/MyDrive/Chat_Analysis/Streamlit/app.py
# Out:
# NgrokTunnel: "http://bc5e-34-125-1-212.ngrok.io" -> "http://localhost:80"
#
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to False.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:80
#   External URL: http://34.125.1.212:80

# %% [markdown]
# # New section

# %%
ngrok.kill()
